# %%
import pandas as pd

# %%
tram_sol = pd.read_csv('Nodes/N-Tram-Sol.csv')
exchanges = pd.read_csv('Edges/Exchanges_with_Wait_Times.csv')
exchanges
# Out:
#            origen       dest                               tram  \
# 0         ST-FRMC  T-T1-FRMC    Francesc Macià - Francesc Macià
# 1       T-T2-FRMC  T-T1-FRMC    Francesc Macià - Francesc Macià
# 2       T-T3-FRMC  T-T1-FRMC    Francesc Macià - Francesc Macià
# 3         ST-FRMC  T-T2-FRMC    Francesc Macià - Francesc Macià
# 4       T-T1-FRMC  T-T2-FRMC    Francesc Macià - Francesc Macià
# ...           ...        ...                                ...
# 131330  B-H8-3797   M-L5-555  Metro Ernest Lluch - Ernest Lluch
# 131331    ST-LLUC   M-L5-555        Ernest Lluch - Ernest Lluch
# 131332  T-T1-LLUC   M-L5-555        Ernest Lluch - Ernest Lluch
# 131333  T-T2-LLUC   M-L5-555        Ernest Lluch - Ernest Lluch
# 131334  T-T3-LLUC   M-L5-555        Ernest Lluch - Ernest Lluch
#
#                      mode         lines             type      time  wait_time  \
# 0             Tram - Tram  IU Stop - T1  Exchange - Self  2.000000   6.601392
# ...
